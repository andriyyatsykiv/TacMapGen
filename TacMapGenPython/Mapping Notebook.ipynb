# %%
import matplotlib.pyplot as plt
import osmnx as osm
import geopandas as gpd

# IMPORT BOUNDING BOX
north = 41.466901
south = 41.462273
east = -74.09598
west = -74.102378

buildingtags = {'building': True}
grasstags = {'landuse': ['grass', 'recreation_ground']}
roadtags = {'highway': ['track', 'footway', 'service'], 'amenity': 'parking'}
watertags = {'natural': 'water'}
foresttags = {'natural': 'wood'}
nametags = {'name': True}

# IMPORT GEODATA
forest = osm.features_from_bbox(north, south, east, west, foresttags)
grass = osm.features_from_bbox(north, south, east, west, grasstags)
water = osm.features_from_bbox(north, south, east, west, watertags)
roads = osm.features_from_bbox(north, south, east, west, roadtags)
buildings = osm.features_from_bbox(north, south, east, west, buildingtags)
names = osm.features_from_bbox(north, south, east, west, nametags)

# %%
names.head(n=10)
# Out:
#                             addr:city addr:housenumber addr:postcode  \
# element_type osmid
# node         8788848014   New Windsor            380 B         12553
#              9709411318   New Windsor              380         12553
#              11186668406          NaN              NaN           NaN
#              11186668407          NaN              NaN           NaN
#              11186668408          NaN              NaN           NaN
#              11186668409          NaN              NaN           NaN
#              11186668410          NaN              NaN           NaN
#              11186668411          NaN              NaN           NaN
#              11186668412          NaN              NaN           NaN
# way          20672565             NaN              NaN           NaN
#
#                          addr:state      addr:street                  name  \
# element_type osmid
# node         8788848014          NY  Mount Airy Road       Grouchy Airsoft
#              9709411318          NY  Mount Airy Road  Zulu24 Airsoft Field
#              11186668406        NaN              NaN                mosque
#              11186668407        NaN              NaN        CONEX / Castle
#              11186668408        NaN              NaN              CQB City
#              11186668409        NaN              NaN            Helicopter
#              11186668410        NaN              NaN               Village
#              11186668411        NaN              NaN            Fuel Depot
#              11186668412        NaN              NaN               Embassy
# way          20672565           NaN              NaN        Bethlehem Road
#
#                          nysgissam:nysaddresspointid    shop    sport  \
# element_type osmid
# node         8788848014                   ORAN121972  sports  airsoft
#              9709411318                          NaN     NaN  airsoft
#              11186668406                         NaN     NaN      NaN
#              11186668407                         NaN     NaN      NaN
#              11186668408                         NaN     NaN      NaN
#              11186668409                         NaN     NaN      NaN
#              11186668410                         NaN     NaN      NaN
#              11186668411                         NaN     NaN      NaN
#              11186668412                         NaN     NaN      NaN
# way          20672565                            NaN     NaN      NaN
#
#                                                                    geometry  \
# element_type osmid
# node         8788848014                          POINT (-74.09936 41.46586)
#              9709411318                          POINT (-74.10008 41.46644)
#              11186668406                         POINT (-74.10095 41.46498)
#              11186668407                         POINT (-74.09992 41.46550)
#              11186668408                         POINT (-74.09998 41.46468)
#              11186668409                         POINT (-74.09882 41.46445)
#              11186668410                         POINT (-74.10159 41.46407)
#              11186668411                         POINT (-74.10062 41.46406)
#              11186668412                         POINT (-74.09925 41.46367)
# way          20672565     LINESTRING (-74.09753 41.44749, -74.09627 41.4...
#
#                           ... tiger:reviewed tiger:zip_left tiger:zip_right  \
# element_type osmid        ...
# node         8788848014   ...            NaN            NaN             NaN
#              9709411318   ...            NaN            NaN             NaN
#              11186668406  ...            NaN            NaN             NaN
#              11186668407  ...            NaN            NaN             NaN
#              11186668408  ...            NaN            NaN             NaN
#              11186668409  ...            NaN            NaN             NaN
#              11186668410  ...            NaN            NaN             NaN
#              11186668411  ...            NaN            NaN             NaN
#              11186668412  ...            NaN            NaN             NaN
# way          20672565     ...             no          12553           12553
#
#                          building height area barrier description amenity  \
# element_type osmid
# node         8788848014       NaN    NaN  NaN     NaN         NaN     NaN
#              9709411318       NaN    NaN  NaN     NaN         NaN     NaN
#              11186668406      NaN    NaN  NaN     NaN         NaN     NaN
#              11186668407      NaN    NaN  NaN     NaN         NaN     NaN
#              11186668408      NaN    NaN  NaN     NaN         NaN     NaN
#              11186668409      NaN    NaN  NaN     NaN         NaN     NaN
#              11186668410      NaN    NaN  NaN     NaN         NaN     NaN
#              11186668411      NaN    NaN  NaN     NaN         NaN     NaN
#              11186668412      NaN    NaN  NaN     NaN         NaN     NaN
# way          20672565         NaN    NaN  NaN     NaN         NaN     NaN
#
#                          shelter_type
# element_type osmid
# node         8788848014           NaN
#              9709411318           NaN
#              11186668406          NaN
#              11186668407          NaN
#              11186668408          NaN
#              11186668409          NaN
#              11186668410          NaN
#              11186668411          NaN
#              11186668412          NaN
# way          20672565             NaN
#
# [10 rows x 27 columns]

# %%
print(names['name'].to_list())
# Out:
# ['Grouchy Airsoft', 'Zulu24 Airsoft Field', 'mosque', 'CONEX / Castle', 'CQB City', 'Helicopter', 'Village', 'Fuel Depot', 'Embassy', 'Bethlehem Road', 'Grouchy Airsoft', 'Truck', 'Truck', 'Truck', 'Chronograph and Shooting Range']

# %%
list(names.columns.values)
# Out:
# ['addr:city',
#  'addr:housenumber',
#  'addr:postcode',
#  'addr:state',
#  'addr:street',
#  'name',
#  'nysgissam:nysaddresspointid',
#  'shop',
#  'sport',
#  'geometry',
#  'leisure',
#  'nodes',
#  'highway',
#  'tiger:cfcc',
#  'tiger:county',
#  'tiger:name_base',
#  'tiger:name_type',
#  'tiger:reviewed',
#  'tiger:zip_left',
#  'tiger:zip_right',
#  'building',
#  'height',
#  'area',
#  'barrier',
#  'description',
#  'amenity',
#  'shelter_type']

# %%
print(names['geometry'].to_list())
# Out:
# [<POINT (-74.099 41.466)>, <POINT (-74.1 41.466)>, <POINT (-74.101 41.465)>, <POINT (-74.1 41.465)>, <POINT (-74.1 41.465)>, <POINT (-74.099 41.464)>, <POINT (-74.102 41.464)>, <POINT (-74.101 41.464)>, <POINT (-74.099 41.464)>, <LINESTRING (-74.098 41.447, -74.096 41.448, -74.096 41.449, -74.096 41.449,...>, <POLYGON ((-74.099 41.466, -74.099 41.466, -74.099 41.466, -74.099 41.466, -...>, <POLYGON ((-74.099 41.465, -74.099 41.465, -74.099 41.465, -74.099 41.465, -...>, <POLYGON ((-74.099 41.465, -74.099 41.465, -74.099 41.465, -74.099 41.465, -...>, <POLYGON ((-74.099 41.465, -74.099 41.465, -74.099 41.465, -74.099 41.465, -...>, <POLYGON ((-74.1 41.467, -74.1 41.467, -74.1 41.467, -74.1 41.467, -74.1 41....>]

# %%
#Try graphing the names (generate plot for names) and then using one of the columns for plot annotation
